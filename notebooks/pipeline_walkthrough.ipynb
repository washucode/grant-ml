# %%
# Cell 1 — imports and path check
import os
import sys
import pandas as pd
import joblib
import numpy as np

print("Python:", sys.version.splitlines()[0])
print("Working dir:", os.getcwd())

# show venv python path (optional)
import sys
print("Executable:", sys.executable)
# Out:
# Python: 3.11.14 (main, Oct  9 2025, 16:16:55) [Clang 16.0.0 (clang-1600.0.26.6)]
# Working dir: /
# Executable: /Users/mac/ML_PLAYGROUND/grant-ml/.venv/bin/python

# %%
# Cell 2 — load raw training data (example)
raw_path = "data/raw/grants_raw.csv"
if not os.path.exists(raw_path):
    # create a tiny dummy file if missing
    os.makedirs("data/raw", exist_ok=True)
    sample = [
        ['"$500,000"','"KES 3,000,000"','4,500,000','"KES 2,500,000"','"KES 90,000"','"KES 60,000"','4',
         "Community org","Strengthen post-harvest handling","Implemented youth training","Empower communities","High"]
    ]
    cols = ["past_grants_total","annual_budget","total_revenue","annual_budget_last_year",
            "cash_reserves","monthly_operating_expenses","years_active",
            "org_background","project_description","track_record","mission_statement","suitability_class"]
    pd.DataFrame(sample, columns=cols).to_csv(raw_path, index=False)
    print("Created dummy data at", raw_path)

df = pd.read_csv(raw_path)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[59], line 5
#       2 raw_path = "data/raw/grants_raw.csv"
#       3 if not os.path.exists(raw_path):
#       4     # create a tiny dummy file if missing
# ----> 5     os.makedirs("data/raw", exist_ok=True)
#       6     sample = [
#       7         ['"$500,000"','"KES 3,000,000"','4,500,000','"KES 2,500,000"','"KES 90,000"','"KES 60,000"','4',
#       8          "Community org","Strengthen post-harvest handling","Implemented youth training","Empower communities","High"]
#       9     ]
#      10     cols = ["past_grants_total","annual_budget","total_revenue","annual_budget_last_year",
#      11             "cash_reserves","monthly_operating_expenses","years_active",
#      12             "org_background","project_description","track_record","mission_statement","suitability_class"]
#
# ...

# %%
import sys
import os

# Get the project root
project_root = os.getcwd()  # Should be the grant-ml folder

# Add src folder to PYTHONPATH
sys.path.append(os.path.join(project_root, "src"))

print(sys.path[-1])  # confirm
# Out:
# /src

# %%
import os
import sys

# Step 1: Move UP ONE directory (from notebooks/ → project root)
os.chdir("..")

print("Now in:", os.getcwd())  # should show /grant-ml

# Step 2: Add src/ folder to Python path
sys.path.append(os.path.join(os.getcwd(), "src"))

print("Python path updated.")

# Step 3: Test import
from preprocessing.full_preprocessor import build_preprocessor

print("🎉 Preprocessor imported successfully!")
# Out:
# Now in: /
# Python path updated.
# 🎉 Preprocessor imported successfully!

# %%
import pandas as pd

df = pd.read_csv("../data/raw/grants_raw.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/raw/grants_raw.csv")
#       4 df.head()
#
# ...

# %%
import os, sys

# move up to project root
os.chdir(".")

# add src to python path
sys.path.append(os.path.join(os.getcwd(), "src"))

print(os.getcwd())
# Out:
# /Users/mac

# %%
from preprocessing.full_preprocessor import build_preprocessor

numeric_cols = [
    "past_grants_total",
    "annual_budget",
    "total_revenue",
    "annual_budget_last_year",
    "cash_reserves",
    "monthly_operating_expenses",
    "years_active",
]

text_cols = [
    "org_background",
    "project_description",
    "track_record",
    "mission_statement",
]

preprocessor = build_preprocessor(numeric_cols, text_cols)
preprocessor
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/ML_PLAYGROUND/grant-ml/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/ML_PLAYGROUND/grant-ml/.venv/lib/python3.11/site-packages/sklearn/utils/_repr_html/base.py:149, in ReprHTMLMixin._repr_mimebundle_(self, **kwargs)
#     147 def _repr_mimebundle_(self, **kwargs):
#     148     """Mime bundle used by jupyter kernels to display estimator"""
# --> 149     output = {"text/plain": repr(self)}
#     150     if get_config()["display"] == "diagram":
#     151         output["text/html"] = self._html_repr()
#
# ...
